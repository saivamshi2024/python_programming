# %%
# Introduction

# %%
print(3 + 2)   # addition(+)
print(3 - 2)   # subtraction(-)
print(3 * 2)   # multiplication(*)
print(3 / 2)   # division(/)
print(3 ** 2)  # exponential(**)
print(3 % 2)   # modulus(%)
print(3 // 2)  # Floor division operator(//)
# Out:
# 5
# 1
# 6
# 1.5
# 9
# 1
# 1

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type(3.14))
# Out:
# <class 'float'>

# %%
print(type(1 + 3j))
# Out:
# <class 'complex'>

# %%
print(type('prabhas'))
# Out:
# <class 'str'>

# %%
print(type([1, 2, 3]))  # List
# Out:
# <class 'list'>

# %%
print(type((9.8, 3.14, 2.7)))  # Tuple
# Out:
# <class 'tuple'>

# %%
print(type({9.8, 3.14, 2.7})) # Set
# Out:
# <class 'set'>

# %%
print(type({'name':'senapati'})) # Dictionary
# Out:
# <class 'dict'>

# %%
print(type(3 == 3))   # Bool
# Out:
# <class 'bool'>

# %%
print(type(3 >= 3))  # Bool
# Out:
# <class 'bool'>

# %% [markdown]
# # # variable || identifier || object
#  ![Screenshot 2025-03-15 221454.png](attachment:e0b13ebf-1fa9-4644-a5b8-a5a8d6d338c8.png)

# %%
2
# Out:
# 2

# %%
x=2#x is variable/identifier/objec, 2 is the value
x
# Out:
# 2

# %%
x + 3
# Out:
# 5

# %%
y = 3
y
# Out:
# 3

# %%
x + y
# Out:
# 5

# %%
x = 9
x
# Out:
# 9

# %%
x + y
# Out:
# 12

# %%
x + 10
# Out:
# 19

# %%
y
# Out:
# 3

# %%
first_name = 'PRAKASH'
print('First name:', first_name)
print('First name length:', len(first_name))
# Out:
# First name: PRAKASH
# First name length: 7

# %%
last_name = 'raj'
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
# Out:
# Last name:  raj
# Last name length:  3

# %%
country = 'HYD'
print('Country: ', country)
# Out:
# Country:  HYD

# %%
city = 'TELENGANA'
print('City: ', city)
# Out:
# City:  TELENGANA

# %%
age = 40087
print('Age: ', age)
# Out:
# Age:  40087

# %%
is_studied = True
print('Studied: ', is_studied)
# Out:
# Studied:  True

# %%
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
print('Skills: ', skills)
# Out:
# Skills:  ['HTML', 'CSS', 'JS', 'React', 'Python']

# %%
person_info = {
    'firstname':'Asabeneh', 
    'lastname':'Yetayeh', 
    'country':'Finland',
    'city':'Helsinki'
    }
print('Person information: ', person_info)
# Out:
# Person information:  {'firstname': 'Asabeneh', 'lastname': 'Yetayeh', 'country': 'Finland', 'city': 'Helsinki'}

# %%
# Declaring multiple variables in one line

first_name, last_name, country, age,is_studied= 'Asabeneh', 'Yetayeh', 'Helsink', 250 ,True

# %%
print(first_name, last_name, country)
# Out:
# Asabeneh Yetayeh Helsink

# %%
print('First name:', first_name)
# Out:
# First name: Asabeneh

# %%
print('Last name: ', last_name)
# Out:
# Last name:  Yetayeh

# %%
print('Country: ', country)
# Out:
# Country:  Helsink

# %%
print('Studied: ', is_studied)
# Out:
# Studied:  True
