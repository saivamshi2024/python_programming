# %% [markdown]
# # string slicing concept--> [:]
#       python index->2 parts
#         forward index->left to right->begins with
#            Backward index->right to left->begings with -1

# %%
s='sai vamshi'
s
# Out:
# 'sai vamshi'

# %%
s
# Out:
# 'sai vamshi'

# %%
s[:]
# Out:
# 'sai vamshi'

# %%
s[1:]
# Out:
# 'ai vamshi'

# %%
s[0:]
# Out:
# 'sai vamshi'

# %%
s[3]
# Out:
# ' '

# %%
s[4] #from left to right -> forward indexing
# Out:
# 'v'

# %%
s[-4] #from right to left -> Backward indexing
# Out:
# 'm'

# %%
s[2]
# Out:
# 'i'

# %%
s[0:3]
# Out:
# 'sai'

# %%
s[1:7]
# Out:
# 'ai vam'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\1733316026.py in <module>
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'sai vamshi'

# %%
s[1:9:2]
# Out:
# 'a as'

# %%
len(s)
# Out:
# 10

# %%
type(s)
# Out:
# str

# %%
s[-1]
# Out:
# 'i'

# %%
s[-3]
# Out:
# 's'

# %%
s[-3:]
# Out:
# 'shi'

# %%
s[:-3]
# Out:
# 'sai vam'

# %%
name1='find'
name1
# Out:
# 'find'

# %%
name1[0:3]
# Out:
# 'fin'

# %%
name1[3]
# Out:
# 'd'

# %%
name1[1:]
# Out:
# 'ind'

# %%
'd' + name1[1:]
# Out:
# 'dind'

# %%
name1
# Out:
# 'find'

# %%
'e'+name1[:5]
# Out:
# 'efind'

# %%
name1
# Out:
# 'find'

# %%
'e'+name1[:-1]
# Out:
# 'efin'

# %%
name1[0:3]+'e'
# Out:
# 'fine'

# %% [markdown]
#  #  introduce to ID()

# %%
# variable address
num = 5
id(num)
# Out:
# 2416187081072

# %%
name = 'nit'
id(name) #Address will be different for both
# Out:
# 2416240718576

# %%
a = 10
id(a)
# Out:
# 2416187081232

# %%
b = a #thats why python is more memory efficient

# %%
id(b)
# Out:
# 2416187081232

# %%
id(10)
# Out:
# 2416187081232

# %%
k = 10 
id(k)
# Out:
# 2416187081232

# %%
a = 20  # as we change the value of a then address will change
id(a)
# Out:
# 2416187081552

# %%
id(b)
# Out:
# 2416187081232

# %% [markdown]
#      * what ever the variale we assigned the memory and we not assigned anywhere then we can use as garbage collection.
#       || VARIABLE - we can change the values
#       || CONSTANT - we cannot change the value -can we make VARIABLE as a CONSTANT (note - in python you cannot make variable as constant)

# %%
PI=3.14
PI
# Out:
# 3.14

# %%
PI=3.13
PI
# Out:
# 3.13

# %% [markdown]
# # Type casting
# ![Screenshot 2025-03-15 213502.png](attachment:572ff66c-ab3d-41a2-9ba9-8f99e4e0b77e.png)

# %%
int(12.3)
# Out:
# 12

# %%
b
# Out:
# 10

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True+False
# Out:
# 1

# %%
True
# Out:
# True

# %%
int("1") #converting the string into the integer
# Out:
# 1

# %%
int(2.3) #cast from float to int
# Out:
# 2

# %%
int(2.3,3.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\2587263345.py in <module>
# ----> 1 int(2.3,3.0)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False) #casting from bool to int
# Out:
# 0

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\1854362543.py in <module>
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten') # we can type cast from all other data type to integer except complex and text string.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\2553255673.py in <module>
# ----> 1 int('ten') # we can type cast from all other data type to integer except complex and text string.
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
float(10) #casting from int to float
# Out:
# 10.0

# %%
float(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\775978943.py in <module>
# ----> 1 float(10,20)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\3226311442.py in <module>
# ----> 1 float(1+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\3331339187.py in <module>
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
complex(10) #casting from int to complex
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\3089141196.py in <module>
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3,4)
# Out:
# (2.3+4j)

# %%
complex(True,True)
# Out:
# (1+1j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\2995795384.py in <module>
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
bool(2) #from int to bool type casting
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25612\3446967011.py in <module>
# ----> 1 bool(2,5)
#
# TypeError: bool expected at most 1 argument, got 2

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool(0+0j)
# Out:
# False

# %%
bool('hi')
# Out:
# True

# %%
bool( ) #space
# Out:
# False

# %%
bool(*)
# Out:
#   File "C:\Users\Sai Vamshi\AppData\Local\Temp\ipykernel_25612\3012113124.py", line 1
#     bool(*)
#           ^
# SyntaxError: invalid syntax

# %%
str(7) #from int to string type catsing
# Out:
# '7'

# %%
str(3.2)
# Out:
# '3.2'

# %%
str(1+3j)
# Out:
# '(1+3j)'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str('hi'*3)
# Out:
# 'hihihi'

# %%
str(21)
# Out:
# '21'

# %% [markdown]
# # Operators
# ![Screenshot 2025-03-16 132331.png](attachment:5b1c2d0d-de9b-453e-b734-7a9ca92be3a6.png)

# %% [markdown]
# #   artithmetic operator (+, -,*, /, **, //, %)

# %%
x1, y1 = 10, 5
print(x1)
print(y1)
# Out:
# 10
# 5

# %%
print(type(x1))
print(type(y1))
# Out:
# <class 'int'>
# <class 'int'>

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1**y1
# Out:
# 100000

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1     #' % ' is to display the remainder
# Out:
# 0

# %%
x2 = 3
y2 = 2
x2 ** y2
# Out:
# 9

# %% [markdown]
# # # assignment operator (+=, -=, *=,/=, //=, **=)

# %%
x=2
x
# Out:
# 2

# %%
x=x+2
x
# Out:
# 4

# %%
x+=2
x
# Out:
# 6

# %%
x+=2
x
# Out:
# 8

# %%
x+=4
x
# Out:
# 12

# %%
x-=2
x
# Out:
# 10

# %%
x*=3
x
# Out:
# 30

# %%
x/=7
x
# Out:
# 4.285714285714286

# %%
x//=4
x
# Out:
# 1.0

# %%
x**=2
x
# Out:
# 1.0

# %%
a, b = 5,6 # you can assigned variable in one line as well

# %%
b
# Out:
# 6

# %%
a
# Out:
# 5

# %% [markdown]
# # unary operator
#      - unary means 1 || binary means 2
#     - Here we are applying unary minus operator(-) on the operand n; the value of m becomes -7, which indicates it as a negative value.

# %%
n=4
n
# Out:
# 4

# %%
m=-(n)
m
# Out:
# -4

# %%
n
# Out:
# 4

# %%
-n
# Out:
# -4

# %%
m
# Out:
# -4

# %% [markdown]
# # relational operator (<, >, <=, >=,!=,==)

# %%
r1=5
r2=6

# %%
print(r1)
print(r2)
# Out:
# 5
# 6

# %%
r1>r2
# Out:
# False

# %%
r1<r2
# Out:
# True

# %%
r1>=r2
# Out:
# False

# %%
r1<=r2
# Out:
# True

# %%
r1==r2
# Out:
# False

# %%
r1!=r2
# Out:
# True

# %%
r1
# Out:
# 5

# %%
r2
# Out:
# 6

# %%
r3=6
r3
# Out:
# 6

# %%
r1==r3
# Out:
# False

# %%
r2==r3
# Out:
# True

# %%
print(r1)
print(r2)
print(r3)
# Out:
# 5
# 6
# 6

# %% [markdown]
# # Logical operator (and,or,not)
# ![Screenshot 2025-03-16 134402.png](attachment:8b20765f-9f59-43f0-adec-2900cbb865c6.png)

# %% [markdown]
# ![Screenshot 2025-03-16 134544.png](attachment:ad101bfd-93c8-4ef1-ba67-f9e5f04883d1.png)

# %%
a=6
b=7

# %%
a<10 and b<5 # Here a<10(True) and b<5(Fale) -> True(1) and False(0) = false  (and-> '*')
# Out:
# False

# %%
a<10 or b<5  # or-> '+'
# Out:
# True

# %%
a<10 and a<8
# Out:
# True

# %%
b>3 and a>5
# Out:
# True

# %%
b>4 and a<=6
# Out:
# True

# %%
x= True
x
# Out:
# True

# %%
not x  # you can reverse the operation
# Out:
# False

# %%
y=False
y

# %%
not y
